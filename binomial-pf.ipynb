# %% [markdown]
# <a href="https://colab.research.google.com/github/jmyers7/MAT-354-Mathematical-Statistics-A/blob/main/binomial-pf.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from scipy.stats import binom
import matplotlib.pyplot as plt

# Define the parameters for the binomial distribution
n = 10  # number of trials
p = 0.5 # probability of success

# Create a range of possible outcomes (x values)
x = np.arange(0, n + 1)

# Calculate the probability mass function (PMF)
pmf = binom.pmf(x, n, p)

# Plot the PMF
plt.figure(figsize=(10, 6))
plt.bar(k, pmf, color='skyblue')
plt.xlabel('Number of Successes (x)')
plt.ylabel('Probability P(X=x)')
plt.title(f'Binomial Probability Function (n={n}, p={p})')
plt.xticks(k)
plt.grid(axis='y', linestyle='--')
plt.show()

# %%
X = binom(n=5, p=0.75)
X.pmf(0) + X.pmf(1) + X.pmf(2) + X.pmf(3)
# Out:
# np.float64(0.3671874999999998)
